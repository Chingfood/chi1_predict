# %%
import numpy as np

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import os

import tensorflow as tf
from tensorflow import keras

tf.__version__
# Out:
# '2.0.0'

# %% [markdown]
# import tensorflow.keras.backend as K
# def customLoss(yTrue,yPred):
#     print("yTrue shape\n")
#     print(yTrue.shape)
#     print("yTrue value\n")
#     print(yTrue)
#     print("yPred shape\n")
#     print(yPred.shape)
#     print("yPred value\n")
#     print(yPred)
#     a = 0
#     if type(yTrue.shape[0]) != int:
#         return 0
#     for i in range(yTrue.shape[0]):
#         a += -(np.log(yPred[i][yTrue[i]]))
#     a = a/yTrue.shape[0]
#     return a

# %%
import tensorflow.keras.backend as K
def customLoss(yTrue,yPred):
    print("yTrue.shape")
    print(yTrue)
    print('\n')
    print("yPred.shape")
    print(yPred)
    print('\n')
    if yTrue.shape[0] == None:
        return 1e-7
    temp = []
    yPred_unpack = tf.unstack(yPred,axis = 1)
    print("I am here\n")
    for num,a in enumerate(yPred_unpack):
        print("I'm inside loop\n")
        print("This is the num:"+str(num)+'\n')
        print("This is a\n")
        print(a)
        print('\n')
        b = K.softmax(a)
        print("this is b\n")
        print(b)
        print('\n')
        print('this is ytrue[num]')
        print(yTrue[0,num])
        print('\n')
        temp.append(K.categorical_crossentropy(yTrue[0,num],b))

    print("I'm outside the loop")
    temp_tensor = tf.concat(temp,0)
    print("all the temp values\n")
    print(temp_tensor)
    print('\n')
    mean = tf.reduce_mean(temp_tensor)
    print("reduced_mean values\n")
    print(mean)
    print('\n')
    return mean

# %%
def create_model_all_conv():
 
    model = tf.keras.models.Sequential()
#convolutional layer with rectified linear unit activation
    model.add(keras.layers.Conv1D(128, kernel_size=1,padding = "Same",
                 activation=tf.keras.activations.relu,
                 input_shape=(None,26)))
#32 convolution filters used each of size 5
#again
    model.add(keras.layers.Conv1D(64, kernel_size=4, padding = "Same", activation=tf.keras.activations.relu))

    model.add(keras.layers.Conv1D(32, kernel_size=4,padding = "Same", activation=tf.keras.activations.relu))    
    model.add(keras.layers.Conv1D(16, kernel_size=4,padding = "Same", activation=tf.keras.activations.relu)) 
    model.add(keras.layers.Conv1D(8, kernel_size=4,padding = "Same", activation=tf.keras.activations.relu)) 
    model.add(keras.layers.Conv1D(4, kernel_size=4,padding = "Same")) 

    model.compile(optimizer=tf.keras.optimizers.Adadelta(),
                loss=customLoss,
                )

    return model

# %%
def input_generator(input_feature, input_label):

    for i in range(input_label.shape[0]):
        shape = list(input_feature[i].shape)
        shape.insert(0,-1)
        yield input_feature[i].reshape(shape), input_label[i].reshape(-1,input_label[i].shape[0])

# %%
train_feature_file_format = "/home/qingyliu/test/training_data/train_feature_0.npy"

train_label_file_format = "/home/qingyliu/test/training_data/train_label_0.npy"

train_features= np.load(train_feature_file_format,allow_pickle=True)
train_labels = np.load(train_label_file_format,allow_pickle=True)

# %%
train_features[0].shape
# Out:
# (141, 26)

# %%
checkpoint_path_all_conv = "/home/qingyliu/test/training_checkpoint/cp.ckpt"
checkpoint_dir_all_conv = os.path.dirname(checkpoint_path_all_conv)
cp_callback_all_conv = tf.keras.callbacks.ModelCheckpoint(checkpoint_path_all_conv,
                                                 save_weights_only=True,
                                                 verbose=1)
model_all_conv = create_model_all_conv()


model_all_conv.fit_generator(input_generator(train_features, train_labels),
                             steps_per_epoch = train_labels.shape[0],
                             epochs = 500,
                             callbacks = [cp_callback_all_conv])
# Out:
# yTrue.shape
# Tensor("conv1d_167_target:0", shape=(None, None, None), dtype=float32)
#
#
# yPred.shape
# Tensor("conv1d_167/Identity:0", shape=(None, None, 4), dtype=float32)
#
#
# Epoch 1/500
# yTrue.shape
# tf.Tensor(
# [[1. 2. 2. 2. 2. 1. 0. 2. 1. 0. 2. 2. 2. 1. 2. 2. 2. 2. 1. 2. 2. 2. 0. 2.
#   2. 2. 1. 1. 2. 1. 2. 2. 2. 2. 1. 1. 0. 0. 2. 2. 2. 1. 2. 1. 3. 1. 2. 2.
#   2. 1. 2. 3. 0. 2. 2. 1. 1. 1. 1. 1. 2. 1. 2. 3. 1. 1. 2. 2. 3. 1. 2. 2.
#   1. 0. 2. 1. 2. 2. 3. 2. 0. 3. 0. 2. 0. 0. 2. 2. 0. 1. 0. 2. 2. 2. 2. 2.
#   2. 1. 0. 1. 3. 1. 1. 2. 2. 2. 2. 2. 1. 0. 2. 1. 2. 0. 1. 2. 0. 1. 0. 3.
#   2. 2. 2. 3. 1. 1. 0. 0. 2. 2. 2. 2. 1. 3. 2. 2. 2. 3. 1. 1. 1.]], shape=(1, 141), dtype=float32)
#
#
# yPred.shape
# tf.Tensor(
# [[[ 2.75298469e-02 -1.83551330e-02 -2.46799067e-02  9.49763320e-03]
#   [ 5.23095429e-02 -5.30566508e-03 -4.47891019e-02 -3.06658074e-02]
#   [ 3.94172370e-02 -2.08532065e-02  1.50723206e-02 -3.08090486e-02]
#   [ 2.55820714e-02  2.97312904e-02 -3.91834192e-02 -4.90949750e-02]
#   [ 8.54441673e-02  1.09444614e-02 -4.56797034e-02 -6.02800064e-02]
#   [ 2.80055106e-02  1.19769201e-02 -7.69649968e-02 -2.80385930e-02]
#   [ 2.80553401e-02 -7.94095080e-03 -4.97007221e-02 -5.42006195e-02]
#   [ 4.72186692e-02 -5.16513586e-02  1.04959868e-02 -2.72286776e-02]
#   [ 7.32681379e-02  1.18435151e-03 -2.84266047e-04 -3.45540382e-02]
#   [ 8.86440277e-02  4.57567163e-02  1.55601166e-02 -7.46528879e-02]
#   [ 7.35769868e-02  4.22341021e-04  2.45084465e-02 -3.85473445e-02]
#   [ 4.89939898e-02 -1.89042639e-03 -7.33532989e-03 -8.15040693e-02]
#   [ 5.06143011e-02 -1.82200763e-02  2.83432472e-02 -2.67771110e-02]
#   [ 5.98030724e-02 -1.70891397e-02 -6.08020686e-02 -7.25964382e-02]
#   [-1.15390178e-02  2.32109670e-02 -2.70217285e-02 -6.01620413e-02]
#   [ 5.03595844e-02 -4.59880708e-03 -2.25920882e-02  1.14707509e-02]
#   [ 5.29421642e-02  6.82179397e-03 -9.43741645e-04 -1.50768701e-02]
#   [ 5.27166650e-02 -2.25657248e-03  9.89087764e-03 -1.92462262e-02]
#   [ 6.19024336e-02  4.91621578e-03 -3.42652993e-03 -9.83112380e-02]
], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2632923  0.23850608 0.2537989  0.24440275]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:8
#
# This is a
#
# tf.Tensor([[ 0.07326814  0.00118435 -0.00028427 -0.03455404]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2661466  0.24763688 0.24727347 0.23894301]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:9
#
# This is a
#
# tf.Tensor([[ 0.08864403  0.04575672  0.01556012 -0.07465289]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26760286 0.2563687  0.24874297 0.22728553]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:10
#
# This is a
#
# tf.Tensor([[ 0.07357699  0.00042234  0.02450845 -0.03854734]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26486516 0.2461808  0.25218233 0.23677173]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:11
#
# This is a
#
# tf.Tensor([[ 0.04899399 -0.00189043 -0.00733533 -0.08150407]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2650218  0.25187367 0.25050598 0.23259856]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:12
#
# This is a
#
# tf.Tensor([[ 0.0506143  -0.01822008  0.02834325 -0.02677711]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26062137 0.24328516 0.2548812  0.24121225]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:13
#
# This is a
#
# tf.Tensor([[ 0.05980307 -0.01708914 -0.06080207 -0.07259644]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27112287 0.251057   0.24031895 0.23750117]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:14
#
# This is a
#
# tf.Tensor([[-0.01153902  0.02321097 -0.02702173 -0.06016204]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25172827 0.2606296  0.24786085 0.23978128]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:15
#
# This is a
#
# tf.Tensor([[ 0.05035958 -0.00459881 -0.02259209  0.01147075]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26055047 0.2466174  0.24221964 0.25061247]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:16
#
# This is a
#
# tf.Tensor([[ 0.05294216  0.00682179 -0.00094374 -0.01507687]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26063997 0.24889214 0.24696685 0.24350098]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:17
#
# This is a
#
# tf.Tensor([[ 0.05271666 -0.00225657  0.00989088 -0.01924623]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2607457  0.24679855 0.2498148  0.24264094]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:18
#
# This is a
#
# tf.Tensor([[ 0.06190243  0.00491622 -0.00342653 -0.09831124]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26785752 0.2530201  0.250918   0.22820435]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:19
#
# This is a
#
# tf.Tensor([[ 0.05287524  0.00891926 -0.0205644  -0.02170661]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26216993 0.2508956  0.24360627 0.24332817]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:20
#
# This is a
#
# tf.Tensor([[ 0.07481982  0.0212951  -0.09302457 -0.12381577]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2767617  0.2623376  0.23399799 0.2269027 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:21
#
# This is a
#
# tf.Tensor([[ 0.06424612 -0.00086939 -0.09080461  0.00289123]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2678222  0.25093848 0.22935538 0.25188395]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:22
#
# This is a
#
# tf.Tensor([[ 0.05314282 -0.01103423 -0.1092729  -0.03316984]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2698885  0.25311193 0.2294289  0.24757071]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:23
#
# This is a
#
# tf.Tensor([[ 0.03512129  0.00525813 -0.00345994 -0.04113508]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25911364 0.2514901  0.24930711 0.24008916]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:24
#
# This is a
#
# tf.Tensor([[ 0.02945486 -0.02186748 -0.04356067 -0.09915456]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26603696 0.25272778 0.24730434 0.23393092]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:25
#
# This is a
#
# tf.Tensor([[ 0.04148732  0.00639801 -0.07452888 -0.08793496]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26776752 0.25853467 0.23843648 0.2352613 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:26
#
# This is a
#
# tf.Tensor([[-0.00167708  0.01188301 -0.07102404 -0.0064379 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2536844  0.25714782 0.23668829 0.25247952]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:27
#
# This is a
#
# tf.Tensor([[ 0.03703178 -0.00337846 -0.02537685 -0.00284918]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2590138  0.24875565 0.24334319 0.24888735]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:28
#
# This is a
#
# tf.Tensor([[ 0.03326443  0.02571074 -0.02939463 -0.10285224]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26284808 0.2608701  0.24688365 0.22939825]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:29
#
# This is a
#
# tf.Tensor([[ 0.04743001 -0.02032399 -0.03822821 -0.02099648]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26411286 0.24681091 0.24243128 0.24664499]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:30
#
# This is a
#
# tf.Tensor([[ 0.11090315  0.04205896  0.02284269 -0.12002535]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.274501   0.25623903 0.2513621  0.21789786]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:31
#
# This is a
#
# tf.Tensor([[ 0.03421875 -0.004801   -0.00245613 -0.0326362 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25899675 0.2490854  0.24967015 0.24224766]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:32
#
# This is a
#
# tf.Tensor([[ 0.15825975  0.02914117 -0.02850453 -0.12134743]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.28863448 0.2536721  0.2394625  0.21823095]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:33
#
# This is a
#
# tf.Tensor([[ 0.08657525  0.05408932 -0.07358125 -0.03789503]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2700505  0.2614186  0.23008583 0.238445  ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:34
#
# This is a
#
# tf.Tensor([[ 0.1137859  -0.01225991 -0.10426831 -0.05565116]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2833025  0.24975224 0.22779839 0.23914692]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:35
#
# This is a
#
# tf.Tensor([[ 0.06371421  0.04483968 -0.10727618 -0.05239782]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2692147  0.26418105 0.22690214 0.23970217]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:36
#
# This is a
#
# tf.Tensor([[ 0.02416068  0.0168044  -0.0387796  -0.00600048]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2562815  0.25440314 0.24064821 0.24866717]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:37
#
# This is a
#
# tf.Tensor([[ 0.04817125  0.00129374 -0.04576083 -0.01164236]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2627093  0.25067833 0.23915598 0.2474564 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:38
#
# This is a
#
# tf.Tensor([[ 0.04622046  0.04388644 -0.04828676 -0.02777655]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26067704 0.2600693  0.23716949 0.24208412]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:39
#
# This is a
#
# tf.Tensor([[-3.9990995e-05 -3.2133749e-04 -4.0112406e-02 -4.5938930e-03]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2527873  0.25271618 0.24285778 0.25163874]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:40
#
# This is a
#
# tf.Tensor([[ 0.044962    0.01839684 -0.04120694 -0.0452587 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26281533 0.2559255  0.24111709 0.2401421 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:41
#
# This is a
#
# tf.Tensor([[ 0.13580558  0.02927479 -0.08007593 -0.11301993]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2869857  0.25798503 0.23126191 0.22376734]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:42
#
# This is a
#
# tf.Tensor([[ 0.04233246  0.07263297 -0.04921975 -0.03225328]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25830412 0.26625064 0.23570603 0.23973924]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:43
#
# This is a
#
# tf.Tensor([[ 0.06315103  0.00912582 -0.05432818 -0.07907419]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2699789  0.25578022 0.24005419 0.2341867 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:44
#
# This is a
#
# tf.Tensor([[ 0.10203089 -0.02122465 -0.13351034 -0.10554797]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2868017  0.25354353 0.22661437 0.23304048]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:45
#
# This is a
#
# tf.Tensor([[ 0.00798238  0.05703889 -0.08087119 -0.03589581]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2549505  0.26776934 0.23327449 0.2440056 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:46
#
# This is a
#
# tf.Tensor([[ 0.02296896  0.00427602 -0.05198114  0.01071933]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25660133 0.25184926 0.2380721  0.25347725]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:47
#
# This is a
#
# tf.Tensor([[ 0.04761726 -0.00083894 -0.02384307 -0.03345047]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26275247 0.25032404 0.24463128 0.24229227]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:48
#
# This is a
#
# tf.Tensor([[ 0.03862105 -0.00680153 -0.01124168  0.00578566]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25808772 0.24662697 0.24553433 0.24975094]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:49
#
# This is a
#
# tf.Tensor([[ 0.03140675  0.01725795  0.00555131 -0.06641988]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25858283 0.25494996 0.25198275 0.2344845 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:50
#
# This is a
#
# tf.Tensor([[ 0.03480176  0.02544948 -0.02469091 -0.04199073]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25913343 0.25672123 0.24416651 0.2399788 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:51
#
# This is a
#
# tf.Tensor([[ 0.06133801 -0.02842084 -0.07695566 -0.0094103 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26905653 0.24595846 0.23430596 0.250679  ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:52
#
# This is a
#
# tf.Tensor([[ 0.03773355  0.03196917 -0.05619589 -0.07645328]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2633873  0.2618734  0.23977382 0.2349655 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:53
#
# This is a
#
# tf.Tensor([[ 0.01420097  0.02936474 -0.02182114 -0.06577273]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2562106  0.26012534 0.24714561 0.23651843]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:54
#
# This is a
#
# tf.Tensor([[ 0.05839649 -0.0148265  -0.00616927 -0.04566176]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2653899  0.24665166 0.24879625 0.23916215]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:55
#
# This is a
#
# tf.Tensor([[ 0.0455174   0.0056326  -0.0209436  -0.04366235]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.262379   0.25212002 0.24550787 0.23999311]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:56
#
# This is a
#
# tf.Tensor([[ 0.07563058  0.02610481 -0.00348722 -0.06747211]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.267217   0.25430527 0.2468901  0.23158765]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:57
#
# This is a
#
# tf.Tensor([[ 0.04079999 -0.02040322  0.01522854  0.01363167]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25716314 0.24189588 0.25067046 0.2502705 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
# I'm inside loop
#
# This is the num:58
#
# This is a
#
# tf.Tensor([[ 0.11399616 -0.00990582 -0.00257304 -0.09990192]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2792621  0.24671869 0.24853447 0.22548479]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:59
#
# This is a
#
# tf.Tensor([[ 0.07906563  0.05908552 -0.01012092 -0.06995115]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26620895 0.26094285 0.24349464 0.22935356]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:60
#
# This is a
#
# tf.Tensor([[ 0.0920302  -0.01738735 -0.00079593 -0.02997358]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27079335 0.24272725 0.24678804 0.23969138]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:61
#
# This is a
#
# tf.Tensor([[ 0.09660733  0.00077447  0.01838372 -0.08905541]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2729312  0.24798961 0.25239518 0.22668399]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:62
#
# This is a
#
# tf.Tensor([[ 0.08263366  0.03990817 -0.0010207  -0.04820488]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26629153 0.25515372 0.24492139 0.23363337]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:63
#
# This is a
#
# tf.Tensor([[ 0.09891996 -0.01416087 -0.03179002 -0.05294086]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27550802 0.24605028 0.24175063 0.2366911 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:64
#
# This is a
#
# tf.Tensor([[ 0.06517892  0.00054712 -0.02064903 -0.02713363]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2654643  0.24884957 0.24363044 0.2420557 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:65
#
# This is a
#
# tf.Tensor([[ 0.0720532  0.0192774 -0.0635594 -0.0658522]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2707859  0.2568655  0.23644505 0.23590356]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:66
#
# This is a
#
# tf.Tensor([[ 0.05328165  0.03309299 -0.0208037  -0.01907636]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2604978  0.25529143 0.2418963  0.2423145 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:67
#
# This is a
#
# tf.Tensor([[ 0.05930605  0.02266319 -0.06888583 -0.04092099]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.266785   0.25718617 0.23468664 0.24134225]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:68
#
# This is a
#
# tf.Tensor([[ 0.08031455  0.02264618 -0.04489259 -0.04628439]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26973343 0.25461835 0.23798962 0.2376586 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:69
#
# This is a
#
# tf.Tensor([[ 0.05359901  0.04998204 -0.10172655 -0.03719505]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26555264 0.26459387 0.22734928 0.2425042 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:70
#
# This is a
#
# tf.Tensor([[ 0.09531928  0.02818167 -0.0574126  -0.02333921]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27162567 0.25398806 0.23315255 0.24123375]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:71
#
# This is a
#
# tf.Tensor([[ 0.03695967  0.02090457 -0.08107765 -0.02768216]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2624576  0.25827748 0.23323633 0.24602859]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:72
#
# This is a
#
# tf.Tensor([[ 0.10347278  0.01476017 -0.07459166 -0.06536615]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27803713 0.25443414 0.23268607 0.23484266]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:73
#
# This is a
#
# tf.Tensor([[ 0.05951828  0.0327255  -0.03717482 -0.03015613]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26346114 0.256496   0.23917913 0.24086377]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:74
#
# This is a
#
# tf.Tensor([[ 0.06772701  0.03133976 -0.02855876 -0.0504123 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26588365 0.2563828  0.24147671 0.23625684]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:75
#
# This is a
#
# tf.Tensor([[ 0.09961049  0.00295711 -0.0357864  -0.05376686]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27479732 0.24948043 0.23999952 0.23572278]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:76
#
# This is a
#
# tf.Tensor([[ 0.04448283 -0.00845987 -0.00144395 -0.00330722]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25927693 0.24590714 0.24763846 0.24717748]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:77
#
# This is a
#
# tf.Tensor([[ 0.09677208  0.00504963 -0.08360515 -0.11592292]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.28123727 0.25658917 0.23482051 0.22735296]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:78
#
# This is a
#
# tf.Tensor([[ 0.04341726  0.0375033  -0.01174276  0.00153441]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25644845 0.2549363  0.24268581 0.24592948]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:79
#
# This is a
#
# tf.Tensor([[ 0.04022958 -0.00509422 -0.03767173 -0.09141552]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26614177 0.2543485  0.24619597 0.23331374]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:80
#
# This is a
#
# tf.Tensor([[ 0.09190007 -0.02548205  0.02503939 -0.1098343 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27458325 0.24417187 0.2568247  0.22442019]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:81
#
# This is a
#
# tf.Tensor([[ 0.06902467  0.06179774 -0.00368751 -0.06115994]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26311627 0.2612216  0.2446635  0.23099855]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:82
#
# This is a
#
# tf.Tensor([[ 0.06834839  0.03541857  0.03089738 -0.06444121]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26270872 0.25419867 0.25305197 0.23004071]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:83
#
# This is a
#
# tf.Tensor([[ 0.07091916 -0.0137826   0.03495337 -0.04085253]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26471075 0.24321261 0.25535938 0.23671716]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:84
#
# This is a
#
# tf.Tensor([[ 0.11493655 -0.00780216 -0.02436373 -0.06987406]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27888379 0.24667123 0.24261962 0.23182541]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:85
#
# This is a
#
# tf.Tensor([[ 0.04189058  0.03361533 -0.01319378 -0.0039997 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25685078 0.25473404 0.24308494 0.2453302 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:86
#
# This is a
#
# tf.Tensor([[ 0.04649548 -0.03471939 -0.0413608  -0.09352809]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26974347 0.24870229 0.24705602 0.23449817]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:87
#
# This is a
#
# tf.Tensor([[ 0.05907597 -0.01498761  0.00975283 -0.03771699]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2639755  0.24513099 0.25127128 0.23962216]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:88
#
# This is a
#
# tf.Tensor([[ 0.03990552  0.00877896  0.01694005 -0.02588526]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2575344  0.24964173 0.2516874  0.24113636]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:89
#
# This is a
#
# tf.Tensor([[ 0.05655833  0.00886625  0.05059261 -0.05996164]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2605869  0.24845065 0.25903693 0.23192555]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:90
#
# This is a
#
# tf.Tensor([[ 0.0437008   0.00436674 -0.0179261  -0.08807733]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26467642 0.25446773 0.24885766 0.23199826]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:91
#
# This is a
#
# tf.Tensor([[ 0.07261045 -0.00366958 -0.01536152 -0.00282098]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26527405 0.24579145 0.2429344  0.24600011]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:92
#
# This is a
#
# tf.Tensor([[ 0.0970407   0.010426   -0.13339752 -0.1879213 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2887454  0.2647883  0.22931741 0.21714891]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:93
#
# This is a
#
# tf.Tensor([[ 0.04710032  0.01049897 -0.11078483  0.01338052]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2642112  0.25471556 0.2256226  0.25545058]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:94
#
# This is a
#
# tf.Tensor([[ 0.08585042  0.01658055 -0.11611452 -0.07362964]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.277563   0.25898707 0.22680327 0.23664661]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:95
#
# This is a
#
# tf.Tensor([[ 0.02631019 -0.02861363  0.02302097 -0.02058635]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25657737 0.24286518 0.25573483 0.24482258]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:96
#
# This is a
#
# tf.Tensor([[ 0.08130206  0.00227337 -0.04868737 -0.12174203]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27636826 0.255368   0.24268027 0.22558346]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:97
#
# This is a
#
# tf.Tensor([[ 0.0326964   0.00886242 -0.04230237 -0.05999694]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26207748 0.25590497 0.24314098 0.23887654]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:98
#
# This is a
#
# tf.Tensor([[ 0.03645732 -0.01430775 -0.03950689 -0.05980499]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2641605  0.25108507 0.244837   0.23991738]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:99
#
# This is a
#
# tf.Tensor([[ 0.0449569  -0.01272569  0.02221151 -0.01922256]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2591145  0.24459101 0.25328737 0.24300708]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:100
#
# This is a
#
# tf.Tensor([[ 0.04080093  0.03212178 -0.01336965 -0.082381  ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26159304 0.25933245 0.24779938 0.23127514]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:101
#
# This is a
#
# tf.Tensor([[ 0.07312057 -0.04562518 -0.05093329 -0.04170778]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27300885 0.24244103 0.24115753 0.24339262]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:102
#
# This is a
#
# tf.Tensor([[ 0.1337696   0.06620963  0.01167054 -0.1174574 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27796477 0.2598058  0.24601568 0.21621372]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:103
#
# This is a
#
# tf.Tensor([[ 0.02921886  0.00235231 -0.032502   -0.04675149]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2603841  0.25348163 0.2447989  0.24133538]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:104
#
# This is a
#
# tf.Tensor([[ 0.14703077  0.0045288  -0.06913926 -0.12076323]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.29087952 0.2522466  0.23433205 0.22254185]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:105
#
# This is a
#
# tf.Tensor([[ 0.0527039   0.07144662 -0.08954975 -0.08429739]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26607847 0.27111253 0.23079678 0.2320122 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:106
#
# This is a
#
# tf.Tensor([[ 0.05573988 -0.03007905 -0.084321   -0.01814761]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.269118   0.24698585 0.23394571 0.24995041]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:107
#
# This is a
#
# tf.Tensor([[ 0.03099716  0.00507486 -0.09675971 -0.02942512]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26344594 0.25670457 0.23185016 0.2479993 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:108
#
# This is a
#
# tf.Tensor([[ 0.03472524  0.04373225 -0.03966871 -0.02082834]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25751194 0.25984183 0.23904985 0.24359635]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:109
#
# This is a
#
# tf.Tensor([[ 0.0141117   0.02675944 -0.01624593 -0.02357011]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25343108 0.25665677 0.24585313 0.24405903]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:110
#
# This is a
#
# tf.Tensor([[ 0.03088321  0.03746975 -0.03570088 -0.03319432]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25772366 0.25942677 0.2411222  0.24172734]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:111
#
# This is a
#
# tf.Tensor([[ 0.08130832  0.00378663 -0.0795655  -0.05082048]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27374503 0.25332555 0.23306638 0.2398631 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:112
#
# This is a
#
# tf.Tensor([[ 0.03680618  0.04166335 -0.02367934 -0.05423474]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25912398 0.26038566 0.24391533 0.23657511]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:113
#
# This is a
#
# tf.Tensor([[ 0.06687085  0.0374658  -0.07835907 -0.05573438]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26878402 0.26099548 0.23245071 0.23776978]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:114
#
# This is a
#
# tf.Tensor([[ 0.04918399  0.04159126 -0.09427679 -0.0362755 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26476872 0.26276603 0.22938365 0.2430816 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:115
#
# This is a
#
# tf.Tensor([[ 0.07192083  0.02220226 -0.04363099 -0.06320621]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26910827 0.25605574 0.23974167 0.23509431]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:116
#
# This is a
#
# tf.Tensor([[ 0.07981541  0.02181793 -0.16077903 -0.09761027]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.28032908 0.2645332  0.22038363 0.23475407]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:117
#
# This is a
#
# tf.Tensor([[-0.00889737  0.05650314 -0.09674493 -0.00107001]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25054213 0.2674754  0.22947165 0.2525109 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:118
#
# This is a
#
# tf.Tensor([[ 0.01543755 -0.00348338 -0.07928547 -0.0110107 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25874692 0.25389722 0.23536263 0.25199324]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:119
#
# This is a
#
# tf.Tensor([[ 0.02041848  0.01443529 -0.02770698 -0.03254466]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25670886 0.2551775  0.24464719 0.24346653]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:120
#
# This is a
#
# tf.Tensor([[ 0.05625211  0.03681028 -0.02409355  0.00019015]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25980613 0.2548038  0.2397484  0.24564163]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:121
#
# This is a
#
# tf.Tensor([[ 0.07106857  0.00569056 -0.04791889 -0.02346871]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26778594 0.25083867 0.23774542 0.24362998]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:122
#
# This is a
#
# tf.Tensor([[ 0.05595248  0.03950491 -0.01183726 -0.11571471]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26592892 0.2615908  0.24849913 0.22398116]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
# I'm inside loop
#
# This is the num:123
#
# This is a
#
# tf.Tensor([[ 0.01135435 -0.01433257 -0.10763668  0.00010983]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2596543  0.25306952 0.2305252  0.25675097]], shape=(1, 4), dtype=float32)
#
#
# ...
#
#
# I'm inside loop
#
# This is the num:171
#
# This is a
#
# tf.Tensor([[ 0.08381079 -0.0315058   0.00224473 -0.03514434]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27022618 0.24079423 0.24905986 0.23991968]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:172
#
# This is a
#
# tf.Tensor([[ 0.08674736 -0.02690488 -0.01843505 -0.05857082]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27341262 0.24403943 0.24611518 0.23643276]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:173
#
# This is a
#
# tf.Tensor([[ 0.04052555  0.02916567 -0.04059293 -0.09248959]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26411423 0.2611309  0.24353562 0.23121929]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:174
#
# This is a
#
# tf.Tensor([[ 0.0411353  -0.00490711 -0.05594008 -0.00031805]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26165113 0.24987721 0.23744516 0.25102654]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:175
#
# This is a
#
# tf.Tensor([[ 0.09738984  0.0071892  -0.02838028 -0.05004689]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27333736 0.24976143 0.24103367 0.23586746]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:176
#
# This is a
#
# tf.Tensor([[-0.01358931  0.00449694  0.0009554  -0.04910292]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25012434 0.2546893  0.25378892 0.24139741]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:177
#
# This is a
#
# tf.Tensor([[ 0.06869221 -0.00647961 -0.0141883  -0.04588075]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26739454 0.24803093 0.24612628 0.23844825]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:178
#
# This is a
#
# tf.Tensor([[ 0.05052331  0.02184328 -0.0172201  -0.05892713]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26298115 0.25554597 0.24575594 0.235717  ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:179
#
# This is a
#
# tf.Tensor([[ 0.02002914  0.0278689  -0.0310996   0.00076808]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25387478 0.2558729  0.24122071 0.24903165]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:180
#
# This is a
#
# tf.Tensor([[ 0.09856047  0.04333126 -0.01662081 -0.06898931]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2715025  0.25691417 0.24196425 0.22961904]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:181
#
# This is a
#
# tf.Tensor([[ 0.07587135  0.03992649 -0.05434866  0.02453505]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2636745  0.25436506 0.23148043 0.25048   ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:182
#
# This is a
#
# tf.Tensor([[ 0.0806988   0.02510089 -0.07524774 -0.07800412]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2736147  0.25881746 0.2341061  0.2334617 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:183
#
# This is a
#
# tf.Tensor([[ 0.06458658  0.02954793 -0.02637121 -0.0546751 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26551962 0.25637728 0.24243435 0.2356687 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:184
#
# This is a
#
# tf.Tensor([[ 0.0576239   0.01185495 -0.09217197 -0.0675687 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27038184 0.25828567 0.23276731 0.23856519]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:185
#
# This is a
#
# tf.Tensor([[ 0.01138079  0.04010398 -0.04946789 -0.01246646]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25338653 0.2607701  0.238428   0.24741542]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:186
#
# This is a
#
# tf.Tensor([[ 0.04005475  0.00144767 -0.05876248 -0.00839992]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26172957 0.25181752 0.23710299 0.2493499 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
# I'm inside loop
#
# This is the num:187
#
# This is a
#
# tf.Tensor([[ 0.04526976  0.01749967  0.01119663 -0.0235206 ]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2582221  0.2511499  0.24957187 0.2410561 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:188
#
# This is a
#
# tf.Tensor([[ 0.04300358  0.0441914  -0.03059627 -0.00277424]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25736806 0.25767395 0.23910609 0.2458519 ]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:189
#
# This is a
#
# tf.Tensor([[ 0.0343659  -0.01406182  0.00190083 -0.03256313]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25933316 0.2470735  0.2510491  0.24254434]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:190
#
# This is a
#
# tf.Tensor([[ 0.08097509  0.00814779 -0.00945193 -0.03507665]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26782858 0.24901667 0.2446724  0.23848237]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:191
#
# This is a
#
# tf.Tensor([[ 0.08878659  0.01039115 -0.04719773 -0.01484378]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27034232 0.24995817 0.23597    0.24372941]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:192
#
# This is a
#
# tf.Tensor([[ 0.07559029  0.04474804  0.01753311 -0.08134383]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26539385 0.25733346 0.2504246  0.22684814]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:193
#
# This is a
#
# tf.Tensor([[ 0.05448274  0.0292609  -0.04064251 -0.05071401]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26423568 0.25765452 0.24025868 0.23785105]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:194
#
# This is a
#
# tf.Tensor([[ 0.13808769  0.00618335 -0.0498933  -0.06066944]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2837037  0.24864498 0.23508553 0.23256582]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:195
#
# This is a
#
# tf.Tensor([[ 0.04234765  0.03317273 -0.07117383 -0.08682907]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26578987 0.2633624  0.23726663 0.23358108]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:196
#
# This is a
#
# tf.Tensor([[ 0.05024195 -0.00479353 -0.08232272 -0.01651568]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26611882 0.25186858 0.2330792  0.24893337]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:197
#
# This is a
#
# tf.Tensor([[ 0.05209002 -0.00094132 -0.05666845 -0.04427783]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2664232  0.2526625  0.2389675  0.24194686]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(1.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:198
#
# This is a
#
# tf.Tensor([[ 0.02051628  0.01475865  0.03737324 -0.02398642]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.25203317 0.25058624 0.2563177  0.24106294]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:199
#
# This is a
#
# tf.Tensor([[ 0.05410175  0.03793556 -0.01924239 -0.06016097]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26279357 0.25857934 0.24420907 0.23441806]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:200
#
# This is a
#
# tf.Tensor([[ 0.05412952  0.00252587 -0.01900416  0.01725383]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2602149  0.24712743 0.24186364 0.25079405]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:201
#
# This is a
#
# tf.Tensor([[ 0.07337795  0.04082423 -0.0698375  -0.08641178]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27123347 0.26254597 0.23504208 0.23117852]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:202
#
# This is a
#
# tf.Tensor([[ 0.03066529  0.05184719 -0.04550125 -0.01292039]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.2560544  0.26153597 0.23727585 0.24513382]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:203
#
# This is a
#
# tf.Tensor([[ 0.09901112  0.02676094 -0.06888232 -0.05190717]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.27505323 0.2558815  0.23254208 0.23652321]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(3.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:204
#
# This is a
#
# tf.Tensor([[ 0.03524085  0.0317367  -0.06501003 -0.05697967]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26225957 0.2613422  0.23724276 0.23915556]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(2.0, shape=(), dtype=float32)
#
#
# I'm inside loop
#
# This is the num:205
#
# This is a
#
# tf.Tensor([[ 0.02904254 -0.01400667 -0.02304172 -0.03866216]], shape=(1, 4), dtype=float32)
#
#
# this is b
#
# tf.Tensor([[0.26030484 0.24933669 0.24709406 0.24326435]], shape=(1, 4), dtype=float32)
#
#
# this is ytrue[num]
# tf.Tensor(0.0, shape=(), dtype=float32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-a0283c53380a> in <module>
#      10                              steps_per_epoch = train_labels.shape[0],
#      11                              epochs = 500,
# ---> 12                              callbacks = [cp_callback_all_conv])
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1295         shuffle=shuffle,
#    1296         initial_epoch=initial_epoch,
# -> 1297         steps_name='steps_per_epoch')
#    1298
#    1299   def evaluate_generator(self,
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     263
#     264       is_deferred = not model._is_compiled
# --> 265       batch_outs = batch_function(*batch_data)
#     266       if not isinstance(batch_outs, list):
#     267         batch_outs = [batch_outs]
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#     971       outputs = training_v2_utils.train_on_batch(
#     972           self, x, y=y, sample_weight=sample_weight,
# --> 973           class_weight=class_weight, reset_metrics=reset_metrics)
#     974       outputs = (outputs['total_loss'] + outputs['output_losses'] +
#     975                  outputs['metrics'])
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in train_on_batch(model, x, y, sample_weight, class_weight, reset_metrics)
#     262       y,
#     263       sample_weights=sample_weights,
# --> 264       output_loss_metrics=model._output_loss_metrics)
#     265
#     266   if reset_metrics:
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_eager.py in train_on_batch(model, inputs, targets, sample_weights, output_loss_metrics)
#     309           sample_weights=sample_weights,
#     310           training=True,
# --> 311           output_loss_metrics=output_loss_metrics))
#     312   if not isinstance(outs, list):
#     313     outs = [outs]
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_eager.py in _process_single_batch(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     250               output_loss_metrics=output_loss_metrics,
#     251               sample_weights=sample_weights,
# --> 252               training=training))
#     253       if total_loss is None:
#     254         raise ValueError('The model cannot be run '
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_eager.py in _model_loss(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     164
#     165         if hasattr(loss_fn, 'reduction'):
# --> 166           per_sample_losses = loss_fn.call(targets[i], outs[i])
#     167           weighted_losses = losses_utils.compute_weighted_loss(
#     168               per_sample_losses,
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/losses.py in call(self, y_true, y_pred)
#     219       y_pred, y_true = tf_losses_util.squeeze_or_expand_dimensions(
#     220           y_pred, y_true)
# --> 221     return self.fn(y_true, y_pred, **self._fn_kwargs)
#     222
#     223   def get_config(self):
#
# <ipython-input-84-e99e3b29ad36> in customLoss(yTrue, yPred)
#      25         print(yTrue[0,num])
#      26         print('\n')
# ---> 27         temp.append(K.categorical_crossentropy(yTrue[0,num],b))
#      28
#      29     print("I'm outside the loop")
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in categorical_crossentropy(target, output, from_logits, axis)
#    4465       # Compute cross entropy from probabilities.
#    4466       epsilon_ = _constant_to_tensor(epsilon(), output.dtype.base_dtype)
# -> 4467       output = clip_ops.clip_by_value(output, epsilon_, 1. - epsilon_)
#    4468       return -math_ops.reduce_sum(target * math_ops.log(output), axis)
#    4469     else:
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/math_ops.py in r_binary_op_wrapper(y, x)
#     923     with ops.name_scope(None, op_name, [x, y]) as name:
#     924       x = ops.convert_to_tensor(x, dtype=y.dtype.base_dtype, name="x")
# --> 925       return func(x, y, name=name)
#     926
#     927   # Propagate func.__doc__ to the wrappers
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_math_ops.py in sub(x, y, name)
#   11070       _result = _pywrap_tensorflow.TFE_Py_FastPathExecute(
#   11071         _ctx._context_handle, _ctx._thread_local_data.device_name, "Sub",
# > 11072         name, _ctx._post_execution_callbacks, x, y)
#   11073       return _result
#   11074     except _core._FallbackException:
#
# KeyboardInterrupt:
