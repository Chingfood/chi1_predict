# %%
import numpy as np

# %%
def range_determine(deg):
    try:
        deg = float(deg)
    except:
        return 4
        
    if (deg <0):
        deg = deg +360
    if deg>=0 and deg <120:
        return 0
    elif deg>=120 and deg <240:
        return 1
    elif deg>=240 and deg <360:
        return 2
    elif deg == 940501:
        return 3
    else:
        return 4

# %% [markdown]
# training_raw_path = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/back_train_scaled.npy"

# %% [markdown]
# training_raw_path = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/whole_seq/hhblits/train_scaled.npy"

# %%
training_raw_path = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/hhblits/train_scaled_0.npy"

# %%
training_raw = np.load(training_raw_path, allow_pickle = True)

# %%
training_raw[0]
# Out:
# array([[ 1.45542329e-01,  1.67906481e-02,  7.17575423e-02,
#          9.37768886e-03,  5.46813172e-02,  4.40763341e-03,
#          9.95180187e-03,  8.95668777e-01,  1.58283140e-02,
#          7.53988716e-01,  9.99875365e-01,  8.24393006e-03,
#          5.70892078e-03,  2.98866798e-02,  9.70886410e-02,
#          7.87103372e-02,  2.76878195e-01,  5.98687660e-01,
#          1.05606880e-02,  2.06332972e-02,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  8.24777743e-02,
#          3.03178167e-01,  6.14344059e-01,  0.00000000e+00,
#         -1.41740000e+02],
#        [ 7.24264854e-02,  1.06656927e-02,  1.53163716e-01,
#          9.70687769e-01,  2.04321873e-02,  2.50869622e-02,
#          7.29087922e-01,  8.86686633e-02,  9.76569332e-01,
#          6.29733561e-02,  3.29598840e-01,  5.42397941e-01,
#          1.50587580e-01,  7.79026108e-01,  8.49412420e-01,
#          2.26181426e-01,  7.95759698e-01,  3.26094553e-02,
#          1.53677056e-02,  4.87502604e-01,  2.86000000e-01,
#          2.00000000e-03,  7.72000000e-01,  9.70146724e-02,
#          3.35741058e-01,  5.67244269e-01,  0.00000000e+00,
#         -1.76360000e+02],
#        [ 2.27539435e-02,  3.84616244e-01,  2.98847234e-03,
#          4.07013772e-03,  6.76995856e-01,  2.26028844e-03,
#          1.14302031e-02,  9.98390145e-01,  6.43210847e-03,
#          7.08890173e-01,  7.64947804e-01,  3.61155053e-03,
#          4.63257072e-03,  7.24623960e-03,  5.54113159e-03,
#          9.01329865e-03,  3.66148283e-02,  7.72063549e-01,
#          9.38773837e-01,  9.42133045e-01,  2.19000000e-01,
#          1.00000000e-03,  8.11000000e-01,  1.33261165e-01,
#          9.88070980e-02,  7.67931737e-01,  0.00000000e+00,
#         -6.15000000e+01],
#        [ 1.57095469e-01,  2.95981042e-02,  3.49781451e-01,
#          5.52307910e-01,  3.03645070e-01,  2.90290358e-02,
#          3.58932594e-01,  5.91458978e-01,  8.30616103e-01,
#          3.89360766e-01,  5.98687660e-01,  2.91109827e-01,
#          1.41851065e-01,  3.49781451e-01,  9.66753691e-01,
#          3.72852234e-01,  6.63738697e-01,  5.22484825e-01,
#          4.69761457e-02,  8.54457671e-01,  6.20000000e-01,
#          2.00000000e-03,  3.89000000e-01,  8.12107160e-02,
#          8.98450632e-06,  8.16078273e-01,  9.01994260e-04,
#          1.94606099e-03,  9.55638172e-01,  3.45559533e-04,
#          9.97295149e-01,  5.09998667e-01,  1.71629642e-04,
#          8.37710325e-06,  1.92673466e-03,  2.43536540e-04,
#          7.92124138e-04,  1.92652326e-02,  3.07890496e-01,
#          2.72617139e-05,  1.48047198e-01,  3.00000000e-03,
#          9.97000000e-01,  0.00000000e+00,  2.00588699e-02,
#          3.29755305e-01,  6.50185825e-01,  0.00000000e+00,
#         -1.70590000e+02]])

# %% [markdown]
# training_feature_file_name = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/back_train_feature_"
# training_label_value_file_name = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/back_train_label_value_"
# training_label_file_name = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/back_train_label_"

# %%
training_feature_file_name = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/hhblits/back_train_feature"
training_label_value_file_name = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/hhblits/back_train_label_value_"
training_label_file_name = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/hhblits/back_train_label"

# %%
train_feature = []
train_label = []
train_label_value=[]
count = 0
for i in range(len(training_raw)):
    for j in range(len(training_raw[i])):
        if len(train_label) > 499: # this number may change to 500*2500
            np.save(training_feature_file_name+str(count),np.asarray(train_feature))
            np.save(training_label_file_name+str(count),np.asarray(train_label))
            np.save(training_label_value_file_name+str(count),np.asarray(train_label_value))
            train_feature = []
            train_label = []
            train_label_value = []
            count += 1

        if training_raw[i][j][-1] != 940501 and training_raw[i][j][-1] != 930524 and training_raw[i][j][0] != 0 and training_raw[i][j][1] !=0 :
            train_feature.append(np.asarray(training_raw[i][j:j+15])[:,:-1])
            train_label.append(training_raw[i][j][-1])
            train_label_value.append(range_determine(training_raw[i][j][-1]))

# %%
train_feature_format="/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/back_train_feature_"
train_label_format = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/back_train_label_value"
train_label_value_format = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/back_train_label_"

raw_train_feature =[] 
raw_train_label = []
raw_train_label_value = []
for i in range(7500,9096):
    raw_train_feature.append(np.load(train_feature_format+str(i)+".npy"))
    raw_train_label.append(np.load(train_label_format+str(i)+".npy"))
    raw_train_label_value.append(np.load(train_label_value_format+str(i)+".npy"))
    
train_label_value = np.concatenate(raw_train_label_value[:], axis =0)
train_feature = np.concatenate(raw_train_feature[:],axis = 0)  
train_label = np.concatenate(raw_train_label[:], axis =0)

np.save("/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/bak.back_train_label_value_new_3",train_label_value)
np.save("/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/back_train_feature_new_3",train_feature)
np.save("/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/back_train_label_value_3",train_label)
