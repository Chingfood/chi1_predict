# %%
import numpy as np
import glob
import random

# %% [markdown]
# folder_path ="/home/qingyliu/test/data"

# %%
folder_path ="/nfs/amino-home/qingyliu/dihedral_angle/hhblits_numpy_new"

# %%
files = sorted(glob.glob(folder_path + '/*.npy'))
arrays = []
for f in files:
    arrays.append(np.load(f))
data = np.asarray(arrays)

# %%
destination_path = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/whole_seq/hhblits/all_data"

# %%
np.save(destination_path,data)

# %%
arrays = random.sample(arrays,len(arrays))

# %%
training_destination_path = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/whole_seq/hhblits/train"
testing_destination_path = "/nfs/amino-home/qingyliu/dihedral_angle/ML_data/whole_seq/hhblits/test"
np.save(training_destination_path,np.asarray(arrays[:-6965]))
np.save(testing_destination_path,np.asarray(arrays[-6965:]))

# %%
folder_path ="/home/qingyliu/test/data/test"
files = sorted(glob.glob(folder_path + '/*.npy'))
arrays = []
for f in files:
    arrays.append(np.load(f))
data = np.asarray(arrays)
np.save("/home/qingyliu/test/testing_data/test",data)

# %%
a = np.load("back_dataset_1.npy", allow_pickle = True)
b = np.load("back_dataset_2.npy", allow_pickle = True)

# %%
c = np.concatenate([a,b])

# %%
c[0][-30:]
# Out:
# [array([-3.20000000e+01, -2.69000000e+02, -3.60000000e+01,  3.82000000e+02,
#         -2.24000000e+02, -2.82000000e+02, -1.41000000e+02, -4.20000000e+01,
#         -3.80000000e+01,  5.20000000e+01, -6.80000000e+01, -1.06000000e+02,
#         -2.15000000e+02,  8.80000000e+01,  4.30000000e+01, -1.07000000e+02,
#         -1.13000000e+02,  1.37000000e+02, -3.16000000e+02, -2.15000000e+02,
#          1.00000000e-02,  9.91000000e-01,  0.00000000e+00,  9.70146724e-02,
#          3.35741058e-01,  5.67244269e-01,  0.00000000e+00, -9.60600000e+01]),
#  array([-2.03000000e+02, -1.94000000e+02, -4.41000000e+02, -3.61000000e+02,
#         -3.10000000e+01, -4.43000000e+02, -3.63000000e+02,  1.10000000e+02,
#         -3.21000000e+02,  4.77000000e+02,  1.36000000e+02, -4.17000000e+02,
#         -3.62000000e+02, -2.91000000e+02, -2.96000000e+02, -3.13000000e+02,
#         -1.76000000e+02,  1.36000000e+02, -2.48000000e+02, -1.78000000e+02,
# ...

# %%
np.save("/nfs/amino-home/qingyliu/dihedral_angle/ML_data/back_tag/back_train", c)
